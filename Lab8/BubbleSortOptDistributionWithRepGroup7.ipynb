# %% [markdown]
# # Bubble sort optimized time complexity, and time complexity histograms for permutations of n different elements with repetions
#
# ## Best case - Increasingly sorted array [1,2,...,n]
#
# $${n-1\ comparisons}$$
# $$ +$$
# $$  \ \ \ \ \ \ \ \ \ \    0 \ \ \ \ \ \ \  \text{swaps}  \ \ \ \ $$
#
# $$T_b(n) = n-1 = \Theta(n^2) $$
#
# ## Worst case - decreasingly sorted array [n,n-1,...,1]
#
# $$\frac{n^2-n}{2} \text{ comparisons}$$
# $$ +$$
# $$ \frac{n^2-n}{2} \ \ \ \ \text{swaps}\ \ \ \ \ \ \ $$
#
# $$T_w(n) = n^2-n = \Theta(n^2) $$
#
# ## Average case over unifrom permutations of n different elements
#
# $$\frac{n^2-n-2}{4} \ \ \ \text{average compaisons }$$
# $$ +$$
# $$ \\\frac{n^2}{4}-\frac{n}{2}+\frac{1}{4} \ \ \ \ \ \  \text{average swaps} \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ $$
#
# $$T_a(n) = \frac{2}{4}(n^2-n-1)= \Theta(n^2) $$

# %%
from itertools import product
 
n = 3
perm = [i for i in product(list(range(1,n+1)),repeat=n)]

c = 0
# Print the obtained permutations
for j in perm:
    print(j)
    c += 1

print(c)
# Out:
# (1, 1, 1)
# (1, 1, 2)
# (1, 1, 3)
# (1, 2, 1)
# (1, 2, 2)
# (1, 2, 3)
# (1, 3, 1)
# (1, 3, 2)
# (1, 3, 3)
# (2, 1, 1)
# (2, 1, 2)
# (2, 1, 3)
# (2, 2, 1)
# (2, 2, 2)
# (2, 2, 3)
# (2, 3, 1)
# (2, 3, 2)
# (2, 3, 3)
# (3, 1, 1)
# (3, 1, 2)
# (3, 1, 3)
# (3, 2, 1)
# (3, 2, 2)
# (3, 2, 3)
# (3, 3, 1)
# (3, 3, 2)
# (3, 3, 3)
# 27

# %%
# https://www.geeksforgeeks.org/bubble-sort/ no optimized adding comaprisons, swaps, steps and passes counters, also fixing "for i in range(n-1):"

def bubbleSortOptAllCounters(arr):

    comps = 0
    swaps = 0
    steps = 0
    passes = 0 
    n = len(arr)
 
    # Traverse through all array elements
    for i in range(n-1):
        swap=False
        passes +=1
        # Last i elements are already in place
        for j in range(0, n-i-1):
 
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            comps +=1
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]
                swaps +=1
                swap=True
        if(swap==False):
          break
    steps = comps + swaps          
    return(comps,swaps,steps,passes)

# %%
def maxinversions(arr):
  maxinv = 0
  n = len(arr) 
  for i in range(n-1):
    inv = 0
    for j in range(i+1,n):
      if arr[j] < arr[i]:
        inv +=1
    if inv > maxinv:
      maxinv = inv
  return maxinv

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 3
perm = [i for i in product(list(range(1,n+1)),repeat=n)]

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    c,sw,st,p = bubbleSortOptAllCounters(i)
    comps.append(c)
    swaps.append(sw)
    steps.append(st)
    passes.append(p)

print("n",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cyan")
plt.title("Bubble Sort Maximun number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximun number of inversions") 
print("Maximun number of inversions exper min =",min(maxinvs))
print("Maximun number of inversions formula min = 0")
print("Maximun number of inversions exper max =",max(maxinvs))
print("Maximun number of inversions formula max n-1 =",n-1)
print("Maximun number of inversions exper mean =",np.mean(maxinvs))
print("Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)=", np.mean(maxinvs))
print("Maximun number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="red")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons formula (n-1)*n/2 =",(n-1)*n/2)
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="blue")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (1/4)*(n^2)-(1/2)*n+(1/4)=",(1/4)*(n**2)-(1/2)*n+(1/4))
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1) =",(n-1))
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (2n^2-n-1)*(1/4) =",np.mean(steps))
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="brown")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n 3
# number of permutations n! = 6
# Maximun number of inversions
# Maximun number of inversions exper min = 0
# Maximun number of inversions formula min = 0
# Maximun number of inversions exper max = 2
# Maximun number of inversions formula max n-1 = 2
# Maximun number of inversions exper mean = 0.8148148148148148
# Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 0.8148148148148148
# Maximun number of inversions exper stdev = 0.7219847662821455
# Comparisons
# Comparisons formula (n-1)*n/2 = 3.0
# Comparisons exper min = 2
# Comparisonsexper max = 3
# Comparisons exper mean = 2.6296296296296298
# Comparisons exper stdev = 0.4829038818668629
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 3
# Swaps max formula (n-1)*n/2 = 3.0
# Swaps exper mean = 1.0
# Swaps mean formula (1/4)*(n^2)-(1/2)*n+(1/4)= 1.0
# Swaps exper stdev = 0.90267093384844
# Steps
# Steps exper min = 2
# Steps min formula (n-1) = 2
# Steps exper max = 6
# Steps max formula (n-1)*n = 6
# Steps exper mean = 3.6296296296296298
# Steps mean formula (2n^2-n-1)*(1/4) = 3.6296296296296298
# Steps exper stdev 1.3374422285383547
# Passes
# Passes formula (n-1) = 2
# Passes exper min = 1
# Passes exper max = 2
# Passes exper mean = 1.6296296296296295
# Passes exper stdev 0.48290388186686284

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 5
perm= [i for i in product(list(range(1,n+1)),repeat=n)]

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    c,sw,st,p = bubbleSortOptAllCounters(i)
    comps.append(c)
    swaps.append(sw)
    steps.append(st)
    passes.append(p)

print("n",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cyan")
plt.title("Bubble Sort Maximun number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximun number of inversions") 
print("Maximun number of inversions exper min =",min(maxinvs))
print("Maximun number of inversions formula min = 0")
print("Maximun number of inversions exper max =",max(maxinvs))
print("Maximun number of inversions formula max n-1 =",n-1)
print("Maximun number of inversions exper mean =",np.mean(maxinvs))
print("Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)=", np.mean(maxinvs))
print("Maximun number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="red")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="blue")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (1/4)*(n^2)-(1/2)*n+(1/4) =", (1/4)*(n**2)-(1/2)*n+(1/4))
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1) =",(n-1))
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (3/4)*(n**2-n) =",np.mean(steps))
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="brown")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n 5
# number of permutations n! = 120
# Maximun number of inversions
# Maximun number of inversions exper min = 0
# Maximun number of inversions formula min = 0
# Maximun number of inversions exper max = 4
# Maximun number of inversions formula max n-1 = 4
# Maximun number of inversions exper mean = 2.21856
# Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 2.21856
# Maximun number of inversions exper stdev = 1.031926124487601
# Comparisons
# Comparisons exper min = 4
# Comparisonsexper max = 10
# Comparisons exper mean = 8.77152
# Comparisons exper stdev = 1.485165610159352
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 10
# Swaps max formula (n-1)*n/2 = 10.0
# Swaps exper mean = 4.0
# Swaps mean formula (1/4)*(n^2)-(1/2)*n+(1/4) = 4.0
# Swaps exper stdev = 2.0
# Steps
# Steps exper min = 4
# Steps min formula (n-1) = 4
# Steps exper max = 20
# Steps max formula (n-1)*n = 20
# Steps exper mean = 12.77152
# Steps mean formula (3/4)*(n**2-n) = 12.77152
# Steps exper stdev 3.2691951440071607
# Passes
# Passes formula (n-1) = 4
# Passes exper min = 1
# Passes exper max = 4
# Passes exper mean = 3.10528
# Passes exper stdev 0.8727634969451918

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 7
perm = [i for i in product(list(range(1,n+1)),repeat=n)]

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    c,sw,st,p = bubbleSortOptAllCounters(i)
    comps.append(c)
    swaps.append(sw)
    steps.append(st)
    passes.append(p)

print("n",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cyan")
plt.title("Bubble Sort Maximun number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximun number of inversions") 
print("Maximun number of inversions exper min =",min(maxinvs))
print("Maximun number of inversions formula min = 0")
print("Maximun number of inversions exper max =",max(maxinvs))
print("Maximun number of inversions formula max n-1 =",n-1)
print("Maximun number of inversions exper mean =",np.mean(maxinvs))
print("Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)=",np.mean(maxinvs))
print("Maximun number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="red")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="blue")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (1/4)*(n^2)-(1/2)*n+(1/4) =", (1/4)*(n**2)-(1/2)*n+(1/4))
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1) =",(n-1))
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (2n^2-n-1)*(1/4) =",np.mean(steps))
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="brown")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n 7
# number of permutations n! = 5040
# Maximun number of inversions
# Maximun number of inversions exper min = 0
# Maximun number of inversions formula min = 0
# Maximun number of inversions exper max = 6
# Maximun number of inversions formula max n-1 = 6
# Maximun number of inversions exper mean = 3.7279632028928664
# Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 3.7279632028928664
# Maximun number of inversions exper stdev = 1.2702839359999143
# Comparisons
# Comparisons exper min = 6
# Comparisonsexper max = 21
# Comparisons exper mean = 18.74813215581943
# Comparisons exper stdev = 2.5376211591556523
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 21
# Swaps max formula (n-1)*n/2 = 21.0
# Swaps exper mean = 9.0
# Swaps mean formula (1/4)*(n^2)-(1/2)*n+(1/4) = 9.0
# Swaps exper stdev = 3.295017884191656
# Steps
# Steps exper min = 6
# Steps min formula (n-1) = 6
# Steps exper max = 42
# Steps max formula (n-1)*n = 42
# Steps exper mean = 27.74813215581943
# Steps mean formula (2n^2-n-1)*(1/4) = 27.74813215581943
# Steps exper stdev 5.373187736730251
# Passes
# Passes formula (n-1) = 6
# Passes exper min = 1
# Passes exper max = 6
# Passes exper mean = 4.6463997629753395
# Passes exper stdev 1.1479990634418065

# %%
# https://www.geeksforgeeks.org/bubble-sort/ no optimized adding only a steps counter, also fixing "for i in range(n-1):"

def bubbleSortOptSteps(arr):

    steps = 0
    n = len(arr)
 
    # Traverse through all array elements
    for i in range(n-1):

        # Last i elements are already in place
        for j in range(0, n-i-1):
            swap=False
 
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            steps +=1
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]
                steps +=1
                swap=True
        if(swap==False):
          break
    return(steps)

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 3
perm = [i for i in product(list(range(1,n+1)),repeat=n)]

times =  [] 
# Print the obtained permutations
for i in perm:
    i = list(i)
    times.append(bubbleSortOptSteps(i))

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1) =",(n-1))
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (2n^2-n-1)*(1/4) =",np.mean(steps))
print("Steps exper stdev",np.std(steps))
print()
# Out:
# Steps
# Steps exper min = 6
# Steps min formula (n-1) = 2
# Steps exper max = 42
# Steps max formula (n-1)*n = 6
# Steps exper mean = 27.74813215581943
# Steps mean formula (2n^2-n-1)*(1/4) = 27.74813215581943
# Steps exper stdev 5.373187736730251

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 5
perm = [i for i in product(list(range(1,n+1)),repeat=n)]

times =  [] 
# Print the obtained permutations
for i in perm:
    i = list(i)
    times.append(bubbleSortOptSteps(i))

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1) =",(n-1))
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (2n^2-n-1)*(1/4) =",(2*n**2-n-1)*(1/4))
print("Steps exper stdev",np.std(steps))
print()
# Out:
# Steps
# Steps exper min = 6
# Steps min formula (n-1) = 4
# Steps exper max = 42
# Steps max formula (n-1)*n = 20
# Steps exper mean = 27.74813215581943
# Steps mean formula (2n^2-n-1)*(1/4) = 11.0
# Steps exper stdev 5.373187736730251

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 8
perm = [i for i in product(list(range(1,n+1)),repeat=n)]

times =  [] 
# Print the obtained permutations
for i in perm:
    i = list(i)
    times.append(bubbleSortOptSteps(i))

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1) =",(n-1))
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (2n^2-n-1)*(1/4) =",(2*n**2-n-1)*(1/4))
print("Steps exper stdev",np.std(steps))
print()
# Out:
# Steps
# Steps exper min = 6
# Steps min formula (n-1) = 7
# Steps exper max = 42
# Steps max formula (n-1)*n = 56
# Steps exper mean = 27.74813215581943
# Steps mean formula (2n^2-n-1)*(1/4) = 29.75
# Steps exper stdev 5.373187736730251

# %%
# https://towardsdatascience.com/an-easy-introduction-to-3d-plotting-with-matplotlib-801561999725
from itertools import permutations
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   times = []

   for P in [i for i in product(list(range(1,n+1)),repeat=n)]:
       t = bubbleSortOptSteps(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.bar3d(x, y, z, dx, dy, dz, color='palegreen', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# https://towardsdatascience.com/an-easy-introduction-to-3d-plotting-with-matplotlib-801561999725
from itertools import permutations
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   times = []

   for P in [i for i in product(list(range(1,n+1)),repeat=n)]:
       t = bubbleSortOptSteps(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.view_init(30, 15)
ax.bar3d(x, y, z, dx, dy, dz, color='palegreen', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
import matplotlib.pyplot as plt
import numpy as np

n = np.arange(1,21,1)

plt.plot(n, (n-1)*n,  label = 'Bubble sort worst time $(n-1)*n$', color='darkgreen')
plt.plot(n, (2*n**2-n-1)*(1/4), label = 'Bubble sort average time $(1/4)*(2*n^2-n-1)$', color='green')
plt.plot(n, (n-1), label = 'Bubble sort best time $(n-1)$',color='lightgreen')
plt.xlabel('Array size')
plt.ylabel('Steps')
plt.legend(loc = 'upper left')

# %% [markdown]
# # Average case - expected number of comparisons + swaps on random unifrom permtation of n diferent elements
#
# $$t_a(n) = \frac{2n^2-n-1}{4}= \Theta(n^2) $$

# %%
# Average case on random unifrom permtation of  3/4 (n**2 -n)
import numpy as np 
import pandas as pd
import scipy.linalg as la

n = np.array([3.0,4.0,6.0,7.0])    # Number n of sorted elments 
t = np.array([3.62,7.47,19.52,27.74]) # Average comparisons + swaps for the corresponding n 

data = pd.DataFrame({'n': n, 't': t})
data
# Out:
#      n      t
# 0  3.0   3.62
# 1  4.0   7.47
# 2  6.0  19.52
# 3  7.0  27.74

# %%
# Interpolating a polynomial of degree 3

X = np.column_stack([n**0,n**1,n**2,n**3])
a = la.solve(X,t)
a
# Out:
# array([ 0.65      , -1.135     ,  0.70333333,  0.00166667])
